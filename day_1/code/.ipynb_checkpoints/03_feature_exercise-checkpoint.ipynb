# %% [markdown]
# # Feature Engineering Exercise

# %%
import pandas as pd

import os

# %% [markdown]
# In this exercise, we will explore different feature engineering ideas.
#
# The feature engineering process can be described as follows:
# 1. Explore your data and answer important questions about your data
#   - What is the format of the data?
#   - How much data do we have?
#   - Describe the data: what columns do we have for each record, and what values do they contain?
#   - Where is the data from?
#   - What problem are we trying to solve?
#   - __What features might we need to solve this problem?__
# 2. Form a hypothesis and gather additional data if needed
#   - Conduct interviews if needed to gain domain knowledge
# 3. Experiment with potential features and understand correlations between them
# 4. Review features with audience and validate domain knowledge
# 5. Build machine learning models and refine your features

# %%
pwd
# Out:
# 'C:\\Users\\deesaw\\Desktop\\MLG-07 USI\\day_1\\code'

# %%
df = pd.read_csv('C:\\Users\\deesaw\\Desktop\\MLG-07 USI\\day_1\\data\\2019 County Health Rankings Data - v2.csv')

# %%
df.describe().T
# Out:
#                                     count          mean            std  \
# FIPS                               3142.0  30383.649268   15162.508374
# Years of Potential Life Lost Rate  2908.0   8522.752063    2636.067751
# % Fair/Poor                        3142.0     17.478994       4.708373
# Physically Unhealthy Days          3142.0      3.921992       0.714785
# Mentally Unhealthy Days            3142.0      3.931604       0.614499
# % LBW                              3035.0      8.111697       2.070856
# % Smokers                          3142.0     17.867919       3.667239
# % Obese                            3142.0     32.125080       4.599871
# Food Environment Index             3123.0      7.465738       1.165679
# % Physically Inactive              3142.0     25.751432       5.182344
# % With Access                      3136.0     62.905931      23.099295
# % Excessive Drinking               3142.0     17.408975       3.263913
# # Alcohol-Impaired Driving Deaths  3109.0     16.178836      37.108846
# # Driving Deaths                   3109.0     56.624317     129.053723
# % Alcohol-Impaired                 3109.0     29.248311      15.220963
# # Chlamydia Cases                  2984.0    531.352212    2038.252400
# Chlamydia Rate                     2984.0    383.461428     256.335531
# Teen Birth Rate                    2998.0     32.105070      15.134145
# # Uninsured                        3141.0   8516.290353   33578.594097
# % Uninsured                        3141.0     11.148997       4.947504
# # Primary Care Physicians          3005.0     81.074210     277.795622
# PCP Rate                           3007.0     54.552378      35.304179
# # Dentists                         3057.0     72.912005     282.895952
# Dentist Rate                       3057.0     45.332025      31.403763
# # Mental Health Providers          2890.0    257.538754     997.818833
# MHP Rate                           2890.0    149.910381     161.041227
# Preventable Hosp. Rate             3104.0   4828.047680    1867.074254
# % Screened                         3123.0     39.963817       7.552950
# % Vaccinated                       3126.0     40.481446       9.742417
# Cohort Size                        2844.0   1273.668425    4039.955931
# Graduation Rate                    3043.0     88.328623       7.464388
# # Some College                     3142.0  17583.228199   62949.242363
# Population                         3142.0  26957.540420   95332.966068
# % Some College                     3142.0     57.609166      11.697803
# # Unemployed                       3141.0   2226.856097    7575.677252
# Labor Force                        3141.0  51126.643107  167676.581648
# % Unemployed                       3141.0      4.619293       1.675839
# % Children in Poverty              3141.0     21.603311       9.112736
# Income Ratio                       3142.0      4.514768       0.745705
# # Single-Parent Households         3141.0   7711.716969   26680.807444
# # Households                       3141.0  23191.958612   75750.525076
# % Single-Parent Households         3141.0     32.394779      10.542520
# # Associations                     3142.0     95.641630     224.785691
# Association Rate                   3142.0     13.783641       7.058226
# Annual Average Violent Crimes      2951.0    408.619451    1776.437767
# Violent Crime Rate                 2951.0    251.902406     192.505391
# # Injury Deaths                    3039.0    355.685752     906.066549
# Injury Death Rate                  3039.0     84.981902      25.747329
# Average Daily PM2.5                3108.0      9.020463       1.966774
# % Severe Housing Problems          3142.0     14.237428       4.684061
# Severe Housing Cost Burden         3142.0     11.417887       3.820066
# Overcrowding                       3142.0      2.401655       2.427235
# % Drive Alone                      3142.0     79.522915       7.675275
# # Workers who Drive Alone          3142.0  36112.274029  112782.185303
# % Long Commute - Drives Alone      3142.0     31.005729      12.402872
#
#                                       min        25%      50%       75%  \
# FIPS                               1001.0  18177.500  29176.0  45080.50
# Years of Potential Life Lost Rate  2900.0   6697.500   8164.5  10045.50
# % Fair/Poor                           8.0     14.000     17.0     20.00
# Physically Unhealthy Days             2.3      3.400      3.9      4.40
# Mentally Unhealthy Days               2.4      3.500      3.9      4.30
# % LBW                                 3.0      7.000      8.0      9.00
# % Smokers                             7.0     15.000     17.0     20.00
# % Obese                              14.0     29.000     32.0     35.00
# Food Environment Index                0.0      6.900      7.7      8.20
# % Physically Inactive                 8.0     22.000     26.0     29.00
# % With Access                         0.0     49.000     66.0     80.00
# % Excessive Drinking                  9.0     15.000     17.0     20.00
# # Alcohol-Impaired Driving Deaths     0.0      3.000      7.0     16.00
# # Driving Deaths                      1.0     13.000     27.0     53.00
# % Alcohol-Impaired                    0.0     20.000     28.0     36.00
# # Chlamydia Cases                     4.0     34.000     96.0    290.00
# Chlamydia Rate                       40.1    217.675    321.7    478.25
# Teen Birth Rate                       2.0     21.000     31.0     42.00
# # Uninsured                          22.0    855.000   2102.0   5532.00
# % Uninsured                           2.0      7.000     10.0     14.00
# # Primary Care Physicians             0.0      4.000     13.0     42.00
# PCP Rate                              0.0     32.000     49.0     71.00
# # Dentists                            0.0      4.000     10.0     36.00
# Dentist Rate                          0.0     26.000     41.0     60.00
# # Mental Health Providers             0.0      7.000     30.0    136.00
# MHP Rate                              0.0     45.000    103.0    200.75
# Preventable Hosp. Rate              471.0   3670.500   4648.0   5752.00
# % Screened                            7.0     35.000     40.0     45.00
# % Vaccinated                          3.0     35.000     42.0     48.00
# Cohort Size                           3.0    156.750    334.0    872.25
# Graduation Rate                      26.0     85.000     90.0     94.00
# # Some College                        7.0   1295.250   3200.0   9361.50
# Population                           12.0   2473.250   6065.5  16165.75
# % Some College                       17.0     49.000     58.0     66.00
# # Unemployed                          5.0    224.000    534.0   1438.00
# Labor Force                         100.0   4930.000  11557.0  31616.00
# % Unemployed                          1.6      3.500      4.4      5.40
# % Children in Poverty                 3.0     15.000     21.0     27.00
# Income Ratio                          2.6      4.000      4.4      4.90
# # Single-Parent Households            0.0    738.000   1887.0   4906.00
# # Households                          7.0   2408.000   5739.0  14895.00
# % Single-Parent Households            0.0     26.000     32.0     38.00
# # Associations                        0.0     15.000     34.0     81.00
# Association Rate                      0.0      9.325     12.6     16.50
# Annual Average Violent Crimes         0.0     17.000     57.0    189.00
# Violent Crime Rate                    0.0    118.000    205.0    335.00
# # Injury Deaths                      10.0     54.000    115.0    280.00
# Injury Death Rate                    26.0     68.500     82.0     97.00
# Average Daily PM2.5                   3.0      7.700      9.4     10.40
# % Severe Housing Problems             3.0     11.000     14.0     16.00
# Severe Housing Cost Burden            1.0      9.000     11.0     13.00
# Overcrowding                          0.0      1.000      2.0      3.00
# % Drive Alone                         5.0     77.000     81.0     84.00
# # Workers who Drive Alone            21.0   3505.250   8537.0  24066.75
# % Long Commute - Drives Alone         0.0     22.000     31.0     40.00
#
#                                          max
# FIPS                                 56045.0
# Years of Potential Life Lost Rate    29783.0
# % Fair/Poor                             41.0
# Physically Unhealthy Days                7.2
# Mentally Unhealthy Days                  6.0
# % LBW                                   26.0
# % Smokers                               43.0
# % Obese                                 50.0
# Food Environment Index                  10.0
# % Physically Inactive                   45.0
# % With Access                          100.0
# % Excessive Drinking                    29.0
# # Alcohol-Impaired Driving Deaths      899.0
# # Driving Deaths                      3410.0
# % Alcohol-Impaired                     100.0
# # Chlamydia Cases                    59116.0
# Chlamydia Rate                        3543.9
# Teen Birth Rate                        110.0
# # Uninsured                         926957.0
# % Uninsured                             33.0
# # Primary Care Physicians             7333.0
# PCP Rate                               477.0
# # Dentists                            8639.0
# Dentist Rate                           725.0
# # Mental Health Providers            31986.0
# MHP Rate                              2003.0
# Preventable Hosp. Rate               33333.0
# % Screened                              62.0
# % Vaccinated                            65.0
# Cohort Size                         122987.0
# Graduation Rate                        100.0
# # Some College                     1860241.0
# Population                         2991750.0
# % Some College                          94.0
# # Unemployed                        240293.0
# Labor Force                        5123933.0
# % Unemployed                            20.1
# % Children in Poverty                   75.0
# Income Ratio                            10.1
# # Single-Parent Households          799251.0
# # Households                       2257133.0
# % Single-Parent Households             100.0
# # Associations                        5713.0
# Association Rate                        70.6
# Annual Average Violent Crimes        49549.0
# Violent Crime Rate                    1820.0
# # Injury Deaths                      19467.0
# Injury Death Rate                      285.0
# Average Daily PM2.5                     19.7
# % Severe Housing Problems               71.0
# Severe Housing Cost Burden              31.0
# Overcrowding                            52.0
# % Drive Alone                           97.0
# # Workers who Drive Alone          3451960.0
# % Long Commute - Drives Alone           85.0

# %%
df.head()
# Out:
#    FIPS    State   County  Years of Potential Life Lost Rate  % Fair/Poor  \
# 0  1001  Alabama  Autauga                             8824.0           18
# 1  1003  Alabama  Baldwin                             7225.0           18
# 2  1005  Alabama  Barbour                             9586.0           26
# 3  1007  Alabama     Bibb                            11784.0           20
# 4  1009  Alabama   Blount                            10908.0           21
#
#    Physically Unhealthy Days  Mentally Unhealthy Days  % LBW  % Smokers  \
# 0                        4.2                      4.3    8.0         19
# 1                        4.1                      4.2    8.0         17
# 2                        5.1                      4.6   11.0         22
# 3                        4.4                      4.3   11.0         20
# 4                        4.5                      4.7    8.0         20
#
#    % Obese  ...  Violent Crime Rate  # Injury Deaths  Injury Death Rate  \
# 0       38  ...               272.0            205.0               74.0
# 1       31  ...               204.0            708.0               69.0
# 2       44  ...               414.0             96.0               73.0
# 3       38  ...                89.0            113.0              100.0
# 4       34  ...               483.0            304.0              105.0
#
#    Average Daily PM2.5  % Severe Housing Problems  Severe Housing Cost Burden  \
# 0                 11.7                         15                          13
# 1                 10.3                         14                          13
# 2                 11.5                         15                          14
# 3                 11.2                         11                          11
# 4                 11.7                         10                           8
#
#    Overcrowding  % Drive Alone  # Workers who Drive Alone  \
# 0             2             86                      20911
# 1             1             85                      74415
# 2             2             83                       7242
# 3             0             86                       6930
# 4             2             87                      18426
#
#    % Long Commute - Drives Alone
# 0                             38
# 1                             41
# 2                             34
# 3                             49
# 4                             60
#
# [5 rows x 57 columns]

# %%
df_copy=df.copy()

# %%
df_copy.head()
# Out:
#    FIPS    State   County  Years of Potential Life Lost Rate  % Fair/Poor  \
# 0  1001  Alabama  Autauga                             8824.0           18
# 1  1003  Alabama  Baldwin                             7225.0           18
# 2  1005  Alabama  Barbour                             9586.0           26
# 3  1007  Alabama     Bibb                            11784.0           20
# 4  1009  Alabama   Blount                            10908.0           21
#
#    Physically Unhealthy Days  Mentally Unhealthy Days  % LBW  % Smokers  \
# 0                        4.2                      4.3    8.0         19
# 1                        4.1                      4.2    8.0         17
# 2                        5.1                      4.6   11.0         22
# 3                        4.4                      4.3   11.0         20
# 4                        4.5                      4.7    8.0         20
#
#    % Obese  ...  Violent Crime Rate  # Injury Deaths  Injury Death Rate  \
# 0       38  ...               272.0            205.0               74.0
# 1       31  ...               204.0            708.0               69.0
# 2       44  ...               414.0             96.0               73.0
# 3       38  ...                89.0            113.0              100.0
# 4       34  ...               483.0            304.0              105.0
#
#    Average Daily PM2.5  % Severe Housing Problems  Severe Housing Cost Burden  \
# 0                 11.7                         15                          13
# 1                 10.3                         14                          13
# 2                 11.5                         15                          14
# 3                 11.2                         11                          11
# 4                 11.7                         10                           8
#
#    Overcrowding  % Drive Alone  # Workers who Drive Alone  \
# 0             2             86                      20911
# 1             1             85                      74415
# 2             2             83                       7242
# 3             0             86                       6930
# 4             2             87                      18426
#
#    % Long Commute - Drives Alone
# 0                             38
# 1                             41
# 2                             34
# 3                             49
# 4                             60
#
# [5 rows x 57 columns]

# %%
df['State'].value_counts()
# Out:
# Texas                   254
# Georgia                 159
# Virginia                133
# Kentucky                120
# Missouri                115
# Kansas                  105
# Illinois                102
# North Carolina          100
# Iowa                     99
# Tennessee                95
# Nebraska                 93
# Indiana                  92
# Ohio                     88
# Minnesota                87
# Michigan                 83
# Mississippi              82
# Oklahoma                 77
# Arkansas                 75
# Wisconsin                72
# Alabama                  67
# Pennsylvania             67
# Florida                  67
# South Dakota             66
# Louisiana                64
# Colorado                 64
# New York                 62
# California               58
# Montana                  56
# West Virginia            55
# North Dakota             53
# South Carolina           46
# Idaho                    44
# Washington               39
# Oregon                   36
# New Mexico               33
# Alaska                   29
# Utah                     29
# Maryland                 24
# Wyoming                  23
# New Jersey               21
# Nevada                   17
# Maine                    16
# Arizona                  15
# Vermont                  14
# Massachusetts            14
# New Hampshire            10
# Connecticut               8
# Rhode Island              5
# Hawaii                    5
# Delaware                  3
# District of Columbia      1
# Name: State, dtype: int64

# %%
import seaborn as sns
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-541c32312790> in <module>
#       1 import seaborn as sns
# ----> 2 sns.pairplot(df)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2092     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2093                     hue_order=hue_order, palette=palette, corner=corner,
# -> 2094                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2095
#    2096     # Add the markers here as PairGrid has figured out how many levels of the
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, corner, diag_sharey, height, aspect, layout_pad, despine, dropna, size)
#    1293                                  figsize=figsize,
#    1294                                  sharex="col", sharey="row",
# -> 1295                                  squeeze=False)
#    1296
#    1297         # Possibly remove upper axes to make a corner grid
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1210     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1211                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1212                        gridspec_kw=gridspec_kw)
#    1213     return fig, axs
#    1214
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1573                 subplot_kw["sharex"] = shared_with[sharex]
#    1574                 subplot_kw["sharey"] = shared_with[sharey]
# -> 1575                 axarr[row, col] = self.add_subplot(gs[row, col], **subplot_kw)
#    1576
#    1577         # turn off redundant tick labeling
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
# -> 1416         return self._add_axes_internal(key, a)
#    1417
#    1418     def _add_axes_internal(self, key, ax):
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in _add_axes_internal(self, key, ax)
#    1419         """Private helper for `add_axes` and `add_subplot`."""
#    1420         self._axstack.add(key, ax)
# -> 1421         self.sca(ax)
#    1422         ax._remove_method = self._remove_ax
#    1423         self.stale = True
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in sca(self, a)
#    1934     def sca(self, a):
#    1935         """Set the current axes to be a and return a."""
# -> 1936         self._axstack.bubble(a)
#    1937         for func in self._axobservers:
#    1938             func(self)
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in bubble(self, a)
#     111         stack, to the top.
#     112         """
# --> 113         return super().bubble(self._entry_from_axes(a))
#     114
#     115     def add(self, key, a):
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in bubble(self, o)
#     733                 bubbles.append(thiso)
#     734             else:
# --> 735                 self.push(thiso)
#     736         for _ in bubbles:
#     737             self.push(o)
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in push(self, o)
#     694         *o* is returned.
#     695         """
# --> 696         self._elements = self._elements[:self._pos + 1] + [o]
#     697         self._pos = len(self._elements) - 1
#     698         return self()
#
# KeyboardInterrupt:

# %%
df.isnull()

# %%
df.isnull.sum()

# %%
df.isnull.any()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
    #OnehotEncoding
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(sparse=False,handle_unknown='ignore'), [1])], remainder='passthrough')
X = ct.fit_transform(df)

# %% [markdown]
# ## Problem: _Predict a County's Health Ranking_

# %%
X
# Out:
# array([[1.0, 0.0, 0.0, ..., 86, 20911, 38],
#        [1.0, 0.0, 0.0, ..., 85, 74415, 41],
#        [1.0, 0.0, 0.0, ..., 83, 7242, 34],
#        ...,
#        [0.0, 0.0, 0.0, ..., 77, 7262, 18],
#        [0.0, 0.0, 0.0, ..., 77, 2845, 11],
#        [0.0, 0.0, 0.0, ..., 73, 2437, 22]], dtype=object)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Data: Long Term Healthcare Facility Data (8 datasets, 2 years, 4 quarters)
#
# https://www.countyhealthrankings.org/explore-health-rankings/rankings-data-documentation
#
# https://data.medicare.gov/data/archives/home-health-compare
#
# Information for research: https://longtermcare.acl.gov/

# %% [markdown]
# #### Assignment
# - Brainstorm features (10 min.)
# - Discuss features as a pair (15 min.)
# - Explore data and research (15 min.)
# - Generate features and explore correlations (30 min.)
